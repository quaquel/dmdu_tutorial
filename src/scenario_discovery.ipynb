# %%
# !pip install ema_workbench\[recommended\]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Scenario Discovery
#
# ## apply the Patient Rule Inducation Method (PRIM) to 100 experiments

# %%
from ema_workbench import load_results, ema_logging

# %%
ema_logging.log_to_stderr(ema_logging.INFO)
# Out:
# <Logger EMA (DEBUG)>

# %%
experiments, outcomes = load_results('./data/100 experiments.tar.gz')

# %%
y = outcomes["deceased population region 1"]

# %%
plt.hist(y, bins=15)
plt.show()

# %%
y_interest = y>1000000

# %%
from ema_workbench.analysis import prim

# %%
prim_alg = prim.Prim(experiments, y_interest, threshold=0.5)
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category

# %%
box1 = prim_alg.find_box()
# Out:
# [MainProcess/INFO] 100 points remaining, containing 39 cases of interest
# [MainProcess/INFO] mean: 0.9705882352941176, mass: 0.34, coverage: 0.8461538461538461, density: 0.9705882352941176 restricted_dimensions: 5

# %%
box1.inspect_tradeoff()
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Apply the Patient Rule Inducation Method (PRIM) to 10000 experiments

# %%
experiments, outcomes = load_results('./data/10000 experiments.tar.gz')
# Out:
# [MainProcess/INFO] results loaded successfully from /Users/jhkwakkel/Documents/GitHub/dmdu_tutorial/src/data/10000 experiments.tar.gz

# %%
y_interest = outcomes["deceased population region 1"]>1000000

prim_alg = prim.Prim(experiments, y_interest, threshold=0.5)
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category

# %%
box1 = prim_alg.find_box()
# Out:
# [MainProcess/INFO] 10000 points remaining, containing 3440 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.0891, coverage: 0.25901162790697674, density: 1.0 restricted_dimensions: 5

# %%
box1.inspect_tradeoff()
# Out:
# alt.VConcatChart(...)
